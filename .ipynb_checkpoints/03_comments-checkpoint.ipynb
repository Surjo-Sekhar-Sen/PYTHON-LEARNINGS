# %%
#comments

# %%
#this is a commement

# %%
#hello
#everyone
#how are you?(well write comments for making you and others understand the perspective of writing the code!!

# %%
"""Hello everyone"""
# Out:
# 'Hello everyone'

# %%
#well not all interpreters are able to read the multiline docstrings type of comments..
#So better use the # sign and then write your comment!!
