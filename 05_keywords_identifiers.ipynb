# %%
#KEYWORDS
import keyword
print(keyword.kwlist) #This way we can see what many keywords are present and used in python!!
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#There are 33 keywords
#Don't use these keywords as Identifiers!!

# %%
#IDENTIFIERS
name="surjo"
print(name)
# Out:
# surjo

# %%
_="hello"
print(_)
# Out:
# hello

# %%
23code="good" #can't use numbers at the start!!
print(23code)
# Out:
#   Cell In[18], line 1
#     23code="good" #can't use numbers at the start!!
#      ^
# SyntaxError: invalid decimal literal

# %%
/hey="bad" #can't use characters other than underscore(_)!!
print(/hey)
# Out:
#   Cell In[17], line 1
#     hey="bad"(#can't, use, characters, other, than, underscore(_)!!)
#              ^
# SyntaxError: '(' was never closed

# %%
code23="good" #can use numbers after!!
print(code23)
# Out:
# good

# %%
False="wrong" #can't use keywords as identifiers!!
print(False)
# Out:
#   Cell In[16], line 1
#     False="wrong" #can't use keywords as identifiers!!
#     ^
# SyntaxError: cannot assign to False
