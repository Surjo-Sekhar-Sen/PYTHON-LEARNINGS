# %%
#IF-ELSE STATEMEMNTS(CONDITIONAL OR DECISION MAKING STATEMENTS)
user_email= input("Give your email id: ")
user_password= input("Give your password: ")

if user_email== "surjosen400@gmail.com" and user_password== "123sss":
    print("Welcome!")
else:
    print("Incrrect credentials!")
# Out:
# Give your email id:  surjonbbnn
# Give your password:  jsuhakd
# Incrrect credentials!

# %%
user_email= input("Give your email id: ")
user_password= input("Give your password: ")

if user_email== "surjosen400@gmail.com" and user_password== "123sss":
    print("Welcome!")
else:
    print("Incrrect credentials!")
# Out:
# Give your email id:  surjosen400@gmail.com
# Give your password:  123sss
# Welcome!

# %%
user_email= input("Give your email id: ")
user_password= input("Give your password: ")

#elif statement 
if user_email== "surjosen400@gmail.com" and user_password== "123sss":
    print("Welcome!")
elif  user_email== "surjosen400@gmail.com" and user_password!= "123sss":
    print("Incorrect password!")
    user_password=input("Type your password again: ")
    if user_password=="123sss":
        print("Correct password, Welcome!")
    else:
        print("Incorrect password again!")
else:
    print("Incrrect credentials!")
# Out:
# Give your email id:  surjosen400@gmail.com
# Give your password:  23sss
# Incorrect password!
# Type your password again:  123sss
# Correct password, Welcome!

# %%
user_email= input("Give your email id: ")
user_password= input("Give your password: ")

if user_email== "surjosen400@gmail.com" and user_password== "123sss":
    print("Welcome!")
elif  user_email== "surjosen400@gmail.com" and user_password!= "123sss":
    print("Incorrect password!")
    user_password=input("Type your password again: ")
    if user_password=="123sss":
        print("Correct password, Welcome!")
    else:
        print("Incorrect password again!")
else:
    print("Incrrect credentials!")
# Out:
# Give your email id:  surjosen400@gmail.com
# Give your password:  23sss
# Incorrect password!
# Type your password again:  12sss
# Incorrect password again!

# %%
user_email= input("Give your email id: ")
user_password= input("Give your password: ")

#Nested if-else statements
if "@" not in user_email:
    print("Incorrect email given!")
    user_email=input("Type your email id again: ")
    if user_email== "surjosen400@gmail.com" and user_password== "123sss":
        print("Welcome!")
    elif  user_email== "surjosen400@gmail.com" and user_password!= "123sss":
        print("Password is also incorrect!")
        user_password=input("Type your password again: ")
        if user_password=="123sss":
            print("Correct password, Welcome!")
        else:
            print("Incorrect password again!")
    else:
        print("Incrrect credentials!")
# Out:
# Give your email id:  surjosen
# Give your password:  23css
# Incorrect email given!
# Type your email id again:  surjosen400@gmail.com
# Password is also incorrect!
# Type your password again:  123sss
# Correct password, Welcome!

# %%
user_email= input("Give your email id: ")
user_password= input("Give your password: ")
if "@" not in user_email:
    print("Incorrect email given!")
    user_email=input("Type your email id again: ")
    if user_email== "surjosen400@gmail.com" and user_password== "123sss":
        print("Welcome!")
    elif  user_email== "surjosen400@gmail.com" and user_password!= "123sss":
        print("Password is also incorrect!")
        user_password=input("Type your password again: ")
        if user_password=="123sss":
            print("Correct password, Welcome!")
        else:
            print("Incorrect password again!")
    else:
        print("Incrrect credentials!")
# Out:
# Give your email id:  surjosen
# Give your password:  123sss
# Incorrect email given!
# Type your email id again:  surjosen400@gmail.com
# Welcome!
