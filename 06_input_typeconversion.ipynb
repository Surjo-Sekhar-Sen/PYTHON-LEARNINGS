# %%
#Input Function
input()
# Out:
#  hello
# 'hello'

# %%
#prompt is the paramter in input function, it's default value is ' '!!
input(prompt="Type your name")
# Out:
# Type your name surjo
# 'surjo'

# %%
first_num=input("Type first number:")
second_num=input("Type second number:")
# Out:
# Type first number: 24
# Type second number: 45

# %%
print(first_num)
print(second_num)
# Out:
# 24
# 45

# %%
result=first_num+second_num
print(result)
# Out:
# 2445

# %%
#We see string concatrnation here, means that 24 and 45 are just strings and joined together!!
#(*THIS HAPPENS BECAUSE input() gets string values in return even if that is a number, this was decided by python developers)
#(*AS STRING IS THE UNIVERSAL FORMAT)..so for checking the datatype of any variable or anything, we can use type() function!!

# %%
type(4)
# Out:
# int

# %%
type(3.6)
# Out:
# float

# %%
type("Hello Everyone")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
type({1,2,3,4,5})
# Out:
# set

# %%
type(first_num)
# Out:
# str

# %%
first_num #WE SEE IT  IS A STRING VALUE!!
# Out:
# '24'

# %%
#TYPE CONVERSION
#THERE ARE TWO WAYS OF TYPE CONVERSION IN PYTHON:
#(implicit and explicit)

# %%
#implicit(python does it itself)
5+ 6+4j
# Out:
# (11+4j)

# %%
4+4.5
# Out:
# 8.5

# %%
4.839+23
# Out:
# 27.839

# %%
#explicit(we have to tell)
first_num=input("Type first number:")
second_num=input("Type second number:")
result=int(first_num)+int(second_num) #do the type conversion earlier when taking input, this will then help you to not do the conversion everytime!!
print(result)
# Out:
# Type first number: 24
# Type second number: 67
# 91

# %%
first_num=int(input("Type first number:"))
second_num=int(input("Type second number:"))
result=(first_num)+(second_num) 
print(result)
# Out:
# Type first number: 34
# Type second number: 78
# 112

# %%
type(first_num)
# Out:
# int

# %%
#IMPORTANT THING: type conversion is a temporary thing which happens!! 
#IN OTHER LANGUAGES LIKE C, C++ the type casting which happens is a permanent thing!!
a=4.5
b=int(a)
print(a)
type(a)
# Out:
# 4.5
# float

# %%
print(b)
type(b)
# Out:
# 4
# int

# %%
#only b is int..the a variable doesn't change it's type!!

# %%
complex(4)
# Out:
# (4+0j)

# %%
int(4.5)
# Out:
# 4

# %%
float(89)
# Out:
# 89.0

# %%
list("Hello Surjo")
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'S', 'u', 'r', 'j', 'o']
