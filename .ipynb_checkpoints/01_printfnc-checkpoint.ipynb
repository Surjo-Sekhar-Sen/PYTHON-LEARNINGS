# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5)
# Out:
# 5

# %%
print(2.5)
# Out:
# 2.5

# %%
print("India","Pakistan","Sri Lanka","Nepal","Myanmar")
# Out:
# India Pakistan Sri Lanka Nepal Myanmar

# %%
print("India",5,2.8,True)
# Out:
# India 5 2.8 True

# %%
print("India","Pakistan","Nepal",sep='-')
# Out:
# India-Pakistan-Nepal

# %%
print("India","Pakistan","Nepal",sep='-', end=" ")
print("Hello world")
# Out:
# India-Pakistan-Nepal Hello world
