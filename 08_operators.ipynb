# %%
#OPERATORS
#(1).ARITHMETIC OPERATORS
x=5
y=2

# %%
x+y #addition
# Out:
# 7

# %%
x-y #subtraction
# Out:
# 3

# %%
x*y #multiplication
# Out:
# 10

# %%
x/y #division
# Out:
# 2.5

# %%
x%y #modulus(remainder)
# Out:
# 1

# %%
x//y #integer division(quotient)
# Out:
# 2

# %%
x**y #exponent(power of)
# Out:
# 25

# %%
y**2
# Out:
# 4

# %%
y**x
# Out:
# 32

# %%
#(2).COMPARISON(RELATIONAL OPERATORS) This give boolean values in return
x>y #greater than
# Out:
# True

# %%
x<y #less than
# Out:
# False

# %%
x == y #equal to
# Out:
# False

# %%
x != y #not equal to
# Out:
# True

# %%
x >= y #greater than or equal to
# Out:
# True

# %%
x <= y #less than or equal to
# Out:
# False

# %%
#(3).LOGICAL OPERATORS
x= True
y= False

# %%
x and y #logical and
# Out:
# False

# %%
x or y #logical or
# Out:
# True

# %%
not x #logical not
# Out:
# False

# %%
not y
# Out:
# True

# %%
#(4).BITWISE OPERATORS
x=2
y=3

# %%
x & y #bitwise and
# Out:
# 2

# %%
x | y #bitwise or
# Out:
# 3

# %%
x ^ y #bitwise xor
# Out:
# 1

# %%
x >> 1 #right shift
# Out:
# 1

# %%
y >> 1
# Out:
# 1

# %%
y >> 2
# Out:
# 0

# %%
x << 1 #left shift
# Out:
# 4

# %%
y << 1
# Out:
# 6

# %%
x << 2
# Out:
# 8

# %%
~ x
# Out:
# -3

# %%
~ y
# Out:
# -4

# %%
#(5).ASSIGNMENT OPERATORS
x=2 #simple assigning

# %%
x+=2 #(x=x+2)

# %%
x
# Out:
# 4

# %%
x-=1 #(x=x-3) #it should have displayed 3 which actually did, but i ran this program two times..so value is 1 now
x
# Out:
# 1

# %%
#remember the number of times you run the program the vlaue of x is changing

# %%
x *=2
x
# Out:
# 2

# %%
x/=2
x
# Out:
# 1.0

# %%
x**3
x
# Out:
# 1.0

# %%
x//=2
x
# Out:
# 0.0

# %%
x+=4

# %%
x
# Out:
# 4.0

# %%
#(6).IDENTITY OPERATORS
x=2
y=3
print(x is y) #is basically helps to find if the values are pointing to the same memory location or not
# Out:
# False

# %%
x=2
y=2
print(x is y)
# Out:
# True

# %%
x="Hello"
y="Hello"
print(x is y)
# Out:
# True

# %%
x="Hello-world"
y="Hello-world"
print(x is y)
# Out:
# False

# %%
x=[1,2,3,4]
y=[1,2,3,4]
print(x is y) #this isn't pointing to the same area!!
# Out:
# False

# %%
x=(1,2,3,4)
y=(1,2,3,4)
print(x is y)
# Out:
# False

# %%
x=(1,2,3,4)
y=(1,2,3,4)
print(x is not y)
# Out:
# True

# %%
#(7).MEMBERSHIP OPERATORS
x=[1,2,3,4]
print(2 in x) #it checks if the value given in present in the value asked or not
# Out:
# True

# %%
print(5 in x)
# Out:
# False

# %%
print (9 not in x)
# Out:
# True

# %%
x = "Hello-world"
print("o" not in x)
# Out:
# False
